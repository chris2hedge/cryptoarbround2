# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters
bitstamp = []
bitstamp_df = pd.read_csv(bitstamp_cvs_path, index_col="date", infer_datetime_format=True, parse_dates=True)
bitstamp_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1133345627.py in <module>
#       4 # Set the parse_dates and infer_datetime_format parameters
#       5 bitstamp = []
# ----> 6 bitstamp_df = pd.read_csv(bitstamp_cvs_path, index_col="date", infer_datetime_format=True, parse_dates=True)
#       7 bitstamp_df.head()
#
# NameError: name 'bitstamp_cvs_path' is not defined

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
bitstamp = pd.Series(np.random.randn(5))
print (bitstamp)
bitstamp.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/3916332253.py in <module>
#       1 # Use the head (and/or tail) function to confirm that the data was imported properly.
# ----> 2 bitstamp = pd.Series(np.random.randn(5))
#       3 print (bitstamp)
#       4 bitstamp.head()
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
coinbase = []
coinbase_df = pd.read_csv(coinbase_cvs_path, index_col="date", infer_datetime_format=True, parse_dates=True)
coinbase.head()
print (coinbase)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1826185188.py in <module>
#       4 # Set the parse_dates and infer_datetime_format parameters
#       5 coinbase = []
# ----> 6 coinbase_df = pd.read_csv(coinbase_cvs_path, index_col="date", infer_datetime_format=True, parse_dates=True)
#       7 coinbase_df.head()
#       8 print (coinbase)
#
# NameError: name 'coinbase_cvs_path' is not defined

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
coinbase = pd.Series(np.random.randn(5))
print (coinbase)
coinbase.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1916017040.py in <module>
#       1 # Use the head (and/or tail) function to confirm that the data was imported properly.
# ----> 2 coinbase = pd.Series(np.random.randn(5))
#       3 print (coinbase)
#       4 coinbase.head()
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
bitstamp_df = df.replace(np.nan,0)
print("bitstamp_df: " strreplace)
bitstamp.dropna()
# Out:
#   Cell In[5], line 3
#     print("bitstamp_df: " strreplace)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $
bitstamp_df = str.replace("$", "")
print("bitstamp_df: " strreplace)
bitstamp.loc[:,"Close"] = bitstamp.loc[:,"Close"].str.replace("$","")
bitstamp.head()
# Out:
#   File "/var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/538132042.py", line 3
#     print("bitstamp_df: " strreplace)
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
bitstamp_df[Close] = df["Close"].astype(float)
print(df.bitstamp)
print(df.dtypes)
bitstamp.loc[:,"Close"] = bitstamp.loc[:,"Close"].astype("float")
bitstamp.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1953752122.py in <module>
#       1 # Convert the Close data type to a float
# ----> 2 bitstamp_df[Close] = df["Close"].astype(float)
#       3 print(df.bitstamp)
#       4 print(df.dtypes)
#       5 bitstamp.loc[:,"Close"] = bitstamp.loc[:,"Close"].astype("float")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
bitstamp.duplicated().sum()

bitstamp = bitstamp.drop_duplicates()
bitstamp.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/2963838045.py in <module>
#       1 # Review the data for duplicate values, and drop them if necessary
# ----> 2 bitstamp.duplicated().sum()
#
# AttributeError: 'list' object has no attribute 'duplicated'

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame
coinbase_df = df.replace(np.nan,0)
print("coinbase_df: " strreplace)

coinbase_df = str.replace("$", "")
print("coinbase_df: " strreplace)

coinbase_df[Close] = df["Close"].astype(float)
print(df.coinbase)
print(df.dtypes)

coinbase.dropna()
coinbase.loc[:,"Close"] = coinbase.loc[:,"Close"].str.replace("$","")
coinbase.head()

coinbase.dtypes

coinbase.loc[:,"Close"] = coinbase.loc[:,"Close"].astype("float")
coinbase.dtypes

coinbase = coinbase.drop_duplicates()
coinbase.duplicated().sum()
# Out:
#   File "/var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/2092533413.py", line 3
#     print("coinbase_df: " strreplace)
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
bitstamp_sliced = loc[row_Timestamp (the index), column_Close]
print(bitstamp_sliced)
# Review the first five rows of the DataFrame
bitstamp_sliced = bitstamp.iloc[:,[3]]

# Review the first five rows of the DataFrame
bitstamp_sliced.head()
# Out:
#   Cell In[9], line 2
#     bitstamp_sliced = loc[row_Timestamp (the index), column_Close]
#                                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
coinbase_sliced = coinbase.iloc[:,[3]]
coinbase_sliced.head()
print(coinbase_sliced)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/2486436444.py in <module>
#       1 # Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
# ----> 2 coinbase_sliced = coinbase.iloc[:,[3]]
#       3 coinbase_sliced.head()
#       4 print(coinbase_sliced)
#
# AttributeError: 'list' object has no attribute 'iloc'

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
bitstamp_df = pd.DataFrame(bitstamp)
print(df.describe())
bitstamp_sliced.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1119585030.py in <module>
#       1 # Generate the summary statistics for the bitstamp DataFrame
#       2 bitstamp_df = pd.DataFrame(bitstamp)
# ----> 3 print(df.describe())
#       4 bitstamp_sliced.describe()
#
# NameError: name 'df' is not defined

# %%
# Generate the summary statistics for the coinbase DataFrame
coinbase_csv.describe(include = "all")
coinbase_sliced.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/3974757322.py in <module>
#       1 # Generate the summary statistics for the coinbase DataFrame
# ----> 2 coinbase_csv.describe(include = "all")
#       3 coinbase_sliced.describe()
#
# NameError: name 'coinbase_csv' is not defined

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
bitstamp_sliced.plot(figsize=(10,5), title="Bitstmp Closing prices", color="blue")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/2758705026.py in <module>
#       1 # Create a line plot for the bitstamp DataFrame for the full length of time in the dataset
#       2 # Be sure that the figure size, title, and color are tailored to each visualization
# ----> 3 bitstamp_sliced.plot(figsize=(10,5), title="Bitstmp Closing prices", color="blue")
#
# NameError: name 'bitstamp_sliced' is not defined

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
coinbase_sliced.plot(figsize=(10,5), title="Coinbase Closing Prices", color="red")
# Out:
# <AxesSubplot:title={'center':'Bitstamp Prices'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp["Close"].plot(legend=True, figsize=(15,7), title="Closing Price Exchange Comparison", color="blue", label="Bitstamp")
coinbase["Close"].plot(legend=True, figsize=(15,7), color="red", label="Coinbase")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/692238409.py in <module>
#       2 # The plot should visualize the prices over the full lenth of the dataset
#       3 # Be sure to include the parameters: legend, figure size, title, and color and label
# ----> 4 bitstamp["Close"].plot(legend=True, figsize=(15,7), title="Closing Price Exchange Comparison", color="blue", label="Bitstamp")
#       5 coinbase["Close"].plot(legend=True, figsize=(15,7), color="orange", label="Coinbase")
#
# TypeError: list indices must be integers or slices, not str

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp["Close"].loc["2018-01-01":"2018-01-31"].plot(
    legend=True, figsize=(15,7), title="Closing Price Exchange Comparison (Jan 1st-Jan 31st)", color="orange", label="Bitstamp")
coinbase["Close"].loc["2018-01-01":"2018-01-31"].plot(
    legend=True, figsize=(15,7), color="blue", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Exchange Comparison (Earlier Time Period)'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 
bitstamp["Close"].loc["2018-03-01":"2018-03-31"].plot(
    legend=True, figsize=(15,7), title="Closing Price Exchange Comparison (March 1st-March 31st)", color="blue", label="Bitstamp")
coinbase["Close"].loc["2018-03-01":"2018-03-31"].plot(
    legend=True, figsize=(15,7), color="orange", label="Coinbase")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1378915451.py in <module>
#       2 # the price action of both DataFrames for a one month period later in the dataset
#       3 # Be sure to include the parameters: legend, figure size, title, and color and label
# ----> 4 bitstamp["Close"].loc["2018-03-01":"2018-03-31"].plot(
#       5     legend=True, figsize=(15,7), title="Closing Price Exchange Comparison (March 1st-March 31st)", color="blue", label="Bitstamp")
#       6 coinbase["Close"].loc["2018-03-01":"2018-03-31"].plot(
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** From observing the visualizations, and different time periods, volatility is higher at the beggining of the specified time period. In the middle of the time period the spreads are least seen, and there is a pick up in the latter 1/3 of the time period selected, although not as strong as in the beggining of this time period selected.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
bitstamp["Close"].loc["2018-01-04"].plot(
    legend=True, figsize=(15,7), title="Arbitrage Profitability Evaluation (Jan 4th)", color="blue", label="Bitstamp")
coinbase["Close"].loc["2018-01-04"].plot(
    legend=True, figsize=(15,7), color="orange", label="Coinbase")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset.
#       2 # Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label`
# ----> 3 joined_data_rows = pd.concat((f_data, coinbase_data, bitstamp_data), axis="rows", join="inner")
#       4 joined_data_rows.head(30-1)
#
# NameError: name 'pd' is not defined

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_early = coinbase["Close"].loc["2018-01-04"] - bitstamp["Close"].loc["2018-01-04"]

# Generate summary statistics for the early DataFrame
arbitrage_spread_early.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1235352998.py in <module>
#       1 # Using the early date that you have selected, calculate the arbitrage spread
#       2 # by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
# ----> 3 arbitrage_spread_early = coinbase["Close"].loc["2018-01-04"] - bitstamp["Close"].loc["2018-01-04"]
#       4
#       5 # Generate summary statistics for the early DataFrame
#
# TypeError: list indices must be integers or slices, not str

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
arbitrage_spread_early.plot(title = "Arbitrage Spread - Early", kind='box')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1966334674.py in <module>
#       1 # Visualize the arbitrage spread from early in the dataset in a box plot
# ----> 2 arbitrage_spread_early.plot(title = "Arbitrage Spread - Early", kind='box')
#       3
#
# NameError: name 'arbitrage_spread_early' is not defined

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
bitstamp["Close"].loc["2018-02-04"].plot(
    legend=True, figsize=(15,7), title="Arbitrage Profitability Evaluation (Feb 4th)", color="blue", label="Bitstamp")
coinbase["Close"].loc["2018-02-04"].plot(
    legend=True, figsize=(15,7), color="orange", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'February 24th, 2018'}, xlabel='Timestamp'>

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_middle = coinbase["Close"].loc["2018-02-04"] - bitstamp["Close"].loc["2018-02-04"]

# Generate summary statistics 
arbitrage_spread_middle.describe()
# Out:
# count    1437.000000
# mean        3.396131
# std        22.969472
# min       -50.180000
# 25%       -10.590000
# 50%        -0.010000
# 75%        12.120000
# max       121.320000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
arbitrage_spread_middle.plot(title = "Arbitrage Spread - Middle", kind='box')
# Out:
#   File "/var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/4145182588.py", line 4
#     boxplt = df.boxplot(column=["Col1", "Col2"])
#          ^
# SyntaxError: invalid syntax

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
bitstamp["Close"].loc["2018-03-07"].plot( 
    legend=True, figsize=(15,7), title="Arbitrage Profitability Evaluation (March 7th)", color="blue", label="Bitstamp")
coinbase["Close"].loc["2018-03-07"].plot(
    legend=True, figsize=(15,7), color="orange", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'March 26th, 2018'}, xlabel='Timestamp'>

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late = coinbase["Close"].loc["2018-03-07"] - bitstamp["Close"].loc["2018-03-07"]

# Generate summary statistics for the late DataFrame
arbitrage_spread_late.describe()
# Out:
# count    1432.000000
# mean       -0.722193
# std         8.523060
# min       -32.040000
# 25%        -6.812500
# 50%        -0.730000
# 75%         4.965000
# max        35.070000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
arbitrage_spread_late.plot(title = "Arbitrage Spread - Late", kind='box')
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Late Date'}>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_early = coinbase["Close"].loc["2018-01-04"] - bitstamp["Close"].loc["2018-01-04"]

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
arbitrage_spread_early[arbitrage_spread_early > 0].describe()

arbitrage_spread_middle = coinbase["Close"].loc["2018-02-04"] - bitstamp["Close"].loc["2018-02-04"]
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
arbitrage_spread_middle[arbitrage_spread_middle > 0].describe()

# For the date late in the dataset, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_late = coinbase["Close"].loc["2018-03-07"] - bitstamp["Close"].loc["2018-03-07"]

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
arbitrage_spread_late[arbitrage_spread_late > 0].describe()
# Out:
# count    960.000000
# mean      53.405344
# std       53.910409
# min        0.010000
# 25%       21.602500
# 50%       39.885000
# 75%       68.547500
# max      606.800000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_early = arbitrage_spread_early[arbitrage_spread_early > 0] / bitstamp["Close"].loc["2018-01-04"]

# Review the spread return DataFrame
spread_return_early

spread_return_middle = arbitrage_spread_middle[arbitrage_spread_middle > 0] / bitstamp["Close"].loc["2018-02-04"]

# Review the spread return DataFrame
spread_return_middle 

spread_return_late = arbitrage_spread_late[arbitrage_spread_late > 0] / bitstamp["Close"].loc["2018-03-07"]

# Review the spread return DataFrame
spread_return_late
# Out:
# Timestamp
# 2018-01-16 00:00:00         NaN
# 2018-01-16 00:01:00         NaN
# 2018-01-16 00:02:00    0.000731
# 2018-01-16 00:03:00    0.001108
# 2018-01-16 00:04:00    0.000909
# Name: Close, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_early = spread_return_early[spread_return_early > .01]

# Review the first five profitable trades
profitable_trades_early.head()

profitable_trades_middle = spread_return_middle[spread_return_middle > .01]

# Review the first five profitable trades
profitable_trades_middle.head()

profitable_trades_late = spread_return_late[spread_return_late > .01]

# Review the first five profitable trades
profitable_trades_late.head()
# Out:
# Timestamp
# 2018-01-16 02:56:00    0.012962
# 2018-01-16 02:57:00    0.010838
# 2018-01-16 02:59:00    0.014171
# 2018-01-16 03:00:00    0.010675
# 2018-01-16 03:06:00    0.019704
# Name: Close, dtype: float64

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
profitable_trades_early.describe()

profitable_trades_middle.describe()

profitable_trades_late.describe()
# Out:
# count    73.000000
# mean      0.016720
# std       0.007628
# min       0.010109
# 25%       0.012061
# 50%       0.014794
# 75%       0.018124
# max       0.051633
# Name: Close, dtype: float64

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
profit_early = profitable_trades_early * bitstamp["Close"].loc["2018-01-04"]

# Drop any missing values from the profit DataFrame
profit_per_trade_early = profit_early.dropna()

# View the early profit DataFrame
profit_per_trade_early

profit_middle = profitable_trades_middle * bitstamp["Close"].loc["2018-02-04"]

# Drop any missing values from the profit DataFrame
profit_per_trade_middle = profit_middle.dropna()

# View the middle profit DataFrame
profit_per_trade_middle

profit_late = profitable_trades_late * bitstamp["Close"].loc["2018-03-07"]

# Drop any missing values from the profit DataFrame
profit_per_trade_late = profit_late.dropna()

# View the late profit DataFrame
profit_per_trade_late
# Out:
# Timestamp
# 2018-01-16 02:56:00    162.01
# 2018-01-16 02:57:00    135.00
# 2018-01-16 02:59:00    176.13
# 2018-01-16 03:00:00    134.01
# 2018-01-16 03:06:00    241.54
#                         ...
# 2018-01-16 19:23:00    125.09
# 2018-01-16 19:26:00    131.78
# 2018-01-16 19:38:00    124.01
# 2018-01-16 19:48:00    117.63
# 2018-01-16 20:07:00    113.69
# Name: Close, Length: 73, dtype: float64

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
profit_per_trade_early.describe()

profit_per_trade_middle.describe()

profit_per_trade_late.describe()
# Out:
# count     73.000000
# mean     193.796849
# std       88.701429
# min      112.520000
# 25%      139.420000
# 50%      171.310000
# 75%      210.060000
# max      606.800000
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
profit_per_trade_early.plot()

profit_per_trade_middle.plot()

profit_per_trade_late.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/1758019707.py in <module>
#       1 # Plot the results for the early profit per trade DataFrame
# ----> 2 profit_per_trade_early.plot()
#
# NameError: name 'profit_per_trade_early' is not defined

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
profit_sum_early = profit_per_trade_early.sum()
profit_sum_early

profit_sum_middle = profit_per_trade_middle.sum()
profit_sum_middle

profit_sum_late = profit_per_trade_late.sum()
profit_sum_late
# Out:
# 14147.169999999998

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
cumulative_profit_early = profit_per_trade_early.cumsum()

cumulative_profit_middle = profit_per_trade_middle.cumsum()

cumulative_profit_late = profit_per_trade_late.cumsum()

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
cumulative_profit_early.plot(title='Cumulative Sum - Early')

cumulative_profit_middle.plot(title='Cumulative Sum - Middle')

cumulative_profit_late.plot(title='Cumulative Sum - Late')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/99/fg1cjgm92j75xmjqnrctbphc0000gn/T/ipykernel_45404/2519967018.py in <module>
#       1 # Plot the cumulative sum of profits for the early profit per trade DataFrame
# ----> 2 cumulative_profit_early.plot(title='Cumulative Sum - Early')
#       3
#       4 cumulative_profit_middle.plot(title='Cumulative Sum - Middle')
#       5
#
# NameError: name 'cumulative_profit_early' is not defined

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** Yes! Upon review of profit information and statistic visualization, profit is increasing over time within each of the periods I observed. This means that the opportunity for arbitrage on Coinbase and Bitstamp exchanges is lower in the begginig of each month and increases in the middle, while reaching the highest point for profit in the last 1/3 of each month. The cumulative sum is essentially growing over each of the separate time periods, so arbitrage profits increase in the later time periods observed.
